# %%
jupyter nbconvert --to webpdf D:\Willis\MLOps\MLOps_Assignment2.ipynb
# Out:
#   Cell In[1], line 1
#     jupyter nbconvert --to webpdf D:\Willis\MLOps\MLOps_Assignment2.ipynb
#             ^
# SyntaxError: invalid syntax
